# %%
import pandas as pd

# %%
df = pd.read_csv('online_course_enrollments.csv')

# %%
df
# Out:
#       Enrollment ID  User ID       Course Name    User Level Enrollment Date
# 0                 1       29     Python Basics      Advanced      2020-03-10
# 1                 2      337      Data Science  Intermediate      2020-10-01
# 2                 3      533      Data Science      Advanced      2020-05-11
# 3                 4      532      Data Science  Intermediate      2023-03-28
# 4                 5       60      Data Science      Advanced      2020-09-09
# ...             ...      ...               ...           ...             ...
# 9995           9996      896  Machine Learning      Advanced      2021-03-24
# 9996           9997      279     Deep Learning      Beginner      2021-02-21
# 9997           9998      680     Deep Learning      Beginner      2021-08-27
# 9998           9999      572     Deep Learning      Beginner      2023-08-24
# 9999          10000      189     Deep Learning      Beginner      2022-07-06
#
# [10000 rows x 5 columns]

# %%
df
# Out:
#       Enrollment ID  User ID       Course Name    User Level Enrollment Date  \
# 0                 1       29     Python Basics      Advanced      2020-03-10
# 1                 2      337      Data Science  Intermediate      2020-10-01
# 2                 3      533      Data Science      Advanced      2020-05-11
# 3                 4      532      Data Science  Intermediate      2023-03-28
# 4                 5       60      Data Science      Advanced      2020-09-09
# ...             ...      ...               ...           ...             ...
# 9995           9996      896  Machine Learning      Advanced      2021-03-24
# 9996           9997      279     Deep Learning      Beginner      2021-02-21
# 9997           9998      680     Deep Learning      Beginner      2021-08-27
# 9998           9999      572     Deep Learning      Beginner      2023-08-24
# 9999          10000      189     Deep Learning      Beginner      2022-07-06
#
#          Status
# 0     Completed
# ...

# %%
import numpy as np

# %%
df['marks'] = np.random.randint(0, 101, size=len(df))

# %%
df
# Out:
#       Enrollment ID  User ID       Course Name    User Level Enrollment Date  \
# 0                 1       29     Python Basics      Advanced      2020-03-10
# 1                 2      337      Data Science  Intermediate      2020-10-01
# 2                 3      533      Data Science      Advanced      2020-05-11
# 3                 4      532      Data Science  Intermediate      2023-03-28
# 4                 5       60      Data Science      Advanced      2020-09-09
# ...             ...      ...               ...           ...             ...
# 9995           9996      896  Machine Learning      Advanced      2021-03-24
# 9996           9997      279     Deep Learning      Beginner      2021-02-21
# 9997           9998      680     Deep Learning      Beginner      2021-08-27
# 9998           9999      572     Deep Learning      Beginner      2023-08-24
# 9999          10000      189     Deep Learning      Beginner      2022-07-06
#
#          Status  marks
# ...

# %%
df
# Out:
#       Enrollment ID  User ID       Course Name    User Level Enrollment Date  \
# 0                 1       29     Python Basics      Advanced      2020-03-10
# 1                 2      337      Data Science  Intermediate      2020-10-01
# 2                 3      533      Data Science      Advanced      2020-05-11
# 3                 4      532      Data Science  Intermediate      2023-03-28
# 4                 5       60      Data Science      Advanced      2020-09-09
# ...             ...      ...               ...           ...             ...
# 9995           9996      896  Machine Learning      Advanced      2021-03-24
# 9996           9997      279     Deep Learning      Beginner      2021-02-21
# 9997           9998      680     Deep Learning      Beginner      2021-08-27
# 9998           9999      572     Deep Learning      Beginner      2023-08-24
# 9999          10000      189     Deep Learning      Beginner      2022-07-06
#
#          Status  marks
# ...

# %%
df['Status']='Completed'

# %%
df
# Out:
#       Enrollment ID  User ID       Course Name    User Level Enrollment Date  \
# 0                 1       29     Python Basics      Advanced      2020-03-10
# 1                 2      337      Data Science  Intermediate      2020-10-01
# 2                 3      533      Data Science      Advanced      2020-05-11
# 3                 4      532      Data Science  Intermediate      2023-03-28
# 4                 5       60      Data Science      Advanced      2020-09-09
# ...             ...      ...               ...           ...             ...
# 9995           9996      896  Machine Learning      Advanced      2021-03-24
# 9996           9997      279     Deep Learning      Beginner      2021-02-21
# 9997           9998      680     Deep Learning      Beginner      2021-08-27
# 9998           9999      572     Deep Learning      Beginner      2023-08-24
# 9999          10000      189     Deep Learning      Beginner      2022-07-06
#
#          Status  marks
# ...

# %%
df['Result'] ='Passed'

# %%
df.loc[df['marks'] < 50, 'Result'] = 'Failed'

# %%
df
# Out:
#       Enrollment ID  User ID       Course Name    User Level Enrollment Date  \
# 0                 1       29     Python Basics      Advanced      2020-03-10
# 1                 2      337      Data Science  Intermediate      2020-10-01
# 2                 3      533      Data Science      Advanced      2020-05-11
# 3                 4      532      Data Science  Intermediate      2023-03-28
# 4                 5       60      Data Science      Advanced      2020-09-09
# ...             ...      ...               ...           ...             ...
# 9995           9996      896  Machine Learning      Advanced      2021-03-24
# 9996           9997      279     Deep Learning      Beginner      2021-02-21
# 9997           9998      680     Deep Learning      Beginner      2021-08-27
# 9998           9999      572     Deep Learning      Beginner      2023-08-24
# 9999          10000      189     Deep Learning      Beginner      2022-07-06
#
#          Status  marks  Result
# ...

# %%
df.loc[df['Result'] == 'Failed', 'Status'] = 'Incomplete'

# %%
df
# Out:
#       Enrollment ID  User ID       Course Name    User Level Enrollment Date  \
# 0                 1       29     Python Basics      Advanced      2020-03-10
# 1                 2      337      Data Science  Intermediate      2020-10-01
# 2                 3      533      Data Science      Advanced      2020-05-11
# 3                 4      532      Data Science  Intermediate      2023-03-28
# 4                 5       60      Data Science      Advanced      2020-09-09
# ...             ...      ...               ...           ...             ...
# 9995           9996      896  Machine Learning      Advanced      2021-03-24
# 9996           9997      279     Deep Learning      Beginner      2021-02-21
# 9997           9998      680     Deep Learning      Beginner      2021-08-27
# 9998           9999      572     Deep Learning      Beginner      2023-08-24
# 9999          10000      189     Deep Learning      Beginner      2022-07-06
#
#           Status  marks  Result
# ...

# %%
df[['Enrollment ID','User ID','Course Name','Enrollment Date','marks','Result','Status']]
# Out:
#       Enrollment ID  User ID       Course Name Enrollment Date  marks  Result  \
# 0                 1       29     Python Basics      2020-03-10     68  Passed
# 1                 2      337      Data Science      2020-10-01     38  Failed
# 2                 3      533      Data Science      2020-05-11     88  Passed
# 3                 4      532      Data Science      2023-03-28     49  Failed
# 4                 5       60      Data Science      2020-09-09     82  Passed
# ...             ...      ...               ...             ...    ...     ...
# 9995           9996      896  Machine Learning      2021-03-24     29  Failed
# 9996           9997      279     Deep Learning      2021-02-21      4  Failed
# 9997           9998      680     Deep Learning      2021-08-27     29  Failed
# 9998           9999      572     Deep Learning      2023-08-24     16  Failed
# 9999          10000      189     Deep Learning      2022-07-06     35  Failed
#
#           Status
# ...

# %%
import seaborn as sns

# %%
sns.histplot(df['Course Name'])
# Out:
# <Axes: xlabel='Course Name', ylabel='Count'>

# %%
sns.histplot(df[df['Course Name']=='Python Basics']['Result'])
# Out:
# <Axes: xlabel='Result', ylabel='Count'>

# %%
sns.displot(df[df['Course Name']=='Data Science']["Status"])
# Out:
# C:\Users\bhara\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame
filtered_df = df[df['Course Name'] == 'Deep Learning']

# Plot the histogram
sns.histplot(data=filtered_df, x='Result')

# Customize the Y-axis label
plt.ylabel('Deep Learning')

plt.show()

# %%
sns.violinplot(data=df, x= df['Course Name']=='Machine Learning',y ='result',hue='Status',split=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 sns.violinplot(data=df, x= df['Course Name']=='Machine Learning',y ='result',hue='Status',split=True)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2305, in violinplot(data, x, y, hue, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2297 def violinplot(
#    2298     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2299     bw="scott", cut=2, scale="area", scale_hue=True, gridsize=100,
#    (...)
#    2302     ax=None, **kwargs,
#    2303 ):
# -> 2305     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2306                              bw, cut, scale, scale_hue, gridsize,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame for "Machine Learning"
ml_df = df[df['Course Name'] == 'Machine Learning']

# Now plot the violin plot
sns.violinplot(data=ml_df, x='Course Name', y='Result', hue='Status', split=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 8
#       5 ml_df = df[df['Course Name'] == 'Machine Learning']
#       7 # Now plot the violin plot
# ----> 8 sns.violinplot(data=ml_df, x='Course Name', y='Result', hue='Status', split=True)
#      10 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2305, in violinplot(data, x, y, hue, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2297 def violinplot(
#    2298     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2299     bw="scott", cut=2, scale="area", scale_hue=True, gridsize=100,
#    (...)
#    2302     ax=None, **kwargs,
#    2303 ):
# -> 2305     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ml_df = df[df['Course Name'] == 'Machine Learning']

sns.violinplot(data=ml_df, x='Course Name', y='marks', hue='Status',split=True)

plt.title('Marks Distribution in Machine Learning')
plt.show()
